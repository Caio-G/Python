# %%
from scipy.stats import pearsonr

# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:/Users/caiog/Workspace/BC Analista de Dados/Desafio Final/TreatedData.xlsx")
data
# Out:
# C:\Users\caiog\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    qtde_portas      ar_condicionado data_inicio_locacao  idade_locatario  \
# 0     2 portas  sem ar condicionado          2021-06-01               23
# 1     4 portas  com ar condicionado          2021-06-03               18
# 2     4 portas  com ar condicionado          2021-04-27               33
# 3     4 portas  com ar condicionado          2021-06-06               21
# 4     4 portas  com ar condicionado          2021-05-13               18
# 5     4 portas  com ar condicionado          2021-05-16               21
# 6     2 portas  com ar condicionado          2021-04-14               28
# 7     2 portas  com ar condicionado          2021-04-14               28
# 8     4 portas  sem ar condicionado          2021-04-17               33
# ...

# %%
co = pearsonr(data.valor_total_locacao,data.cotacao_dolar)
co
# Out:
# (-0.036965031807549245, 0.8842219523888895)

# %%
data.idade_locatario
